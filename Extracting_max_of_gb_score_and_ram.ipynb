# %% [markdown]
# ## **import dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **import libraries**

# %%
import pandas as pd
import numpy as np

# %%
pc_details = pd.read_csv(r'/content/drive/MyDrive/dataset/cleaned_old_dataset.csv')
pc_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1293 non-null   int64
#  1   Unnamed: 0.1        1293 non-null   int64
#  2   team_id             1293 non-null   int64
#  3   Single core score1  1293 non-null   float64
#  4   Single core score2  1293 non-null   float64
#  5   Single core score3  1293 non-null   float64
#  6   Single core score4  1293 non-null   float64
#  7   Multi core score1   1293 non-null   float64
#  8   Multi core score2   1293 non-null   float64
#  9   Multi core score3   1293 non-null   float64
#  10  Multi core score4   1293 non-null   float64
#  11  OpenCL score1       1293 non-null   float64
#  12  OpenCL score2       1293 non-null   float64
#  13  OpenCL score3       1293 non-null   float64
#  14  OpenCL score4       1293 non-null   float64
# ...

# %%
pc_details.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'team_id', 'Single core score1',
#        'Single core score2', 'Single core score3', 'Single core score4',
#        'Multi core score1', 'Multi core score2', 'Multi core score3',
#        'Multi core score4', 'OpenCL score1', 'OpenCL score2', 'OpenCL score3',
#        'OpenCL score4', 'OS1', 'OS2', 'OS3', 'OS4', 'Model1', 'Model2',
#        'Model3', 'Model4', 'CPU1', 'CPU2', 'CPU3', 'CPU4', 'Memory1',
#        'Memory2', 'Memory3', 'Memory4', 'Graphic Card1', 'Graphic Card2',
#        'Graphic Card3', 'Graphic Card4'],
#       dtype='object')

# %%
pc_details = pc_details.drop(['Unnamed: 0.1', 'Single core score1', 'Single core score2', 'Single core score3', 
                 'Single core score4','OpenCL score1', 'OpenCL score2', 'OpenCL score3',
                 'OpenCL score4', 'OS1', 'OS2', 'OS3', 'OS4', 'Model1', 'Model2','Model3', 'Model4',
                 'CPU1', 'CPU2', 'CPU3', 'CPU4','Graphic Card1', 'Graphic Card2', 'Graphic Card3', 'Graphic Card4'], axis=1)

# %%
pc_details
# Out:
#       Unnamed: 0  team_id  Multi core score1  Multi core score2  \
# 0              0     1001             2148.0             1132.0
# 1              1     1002             3394.0             1834.0
# 2              2     1004             2303.0             6647.0
# 3              3     1005             3318.0             3848.0
# 4              4     1006             2612.0             1127.0
# ...          ...      ...                ...                ...
# 1288        1288     2964             1101.0             2845.0
# 1289        1289     2965             4373.0                0.0
# 1290        1290     2968                0.0                0.0
# 1291        1291     2970                0.0                0.0
# 1292        1292     2971                0.0                0.0
#
#       Multi core score3  Multi core score4  Memory1  Memory2  Memory3  Memory4
# 0                1525.0             2281.0     3.62     3.64     3.73     5.74
# ...

# %%
pc_details['Geekbench_score'] = pc_details[['Multi core score1', 'Multi core score2', 'Multi core score3','Multi core score4']].values.max(1)

# %%
pc_details.head()
# Out:
#    Unnamed: 0  team_id  Multi core score1  Multi core score2  \
# 0           0     1001             2148.0             1132.0
# 1           1     1002             3394.0             1834.0
# 2           2     1004             2303.0             6647.0
# 3           3     1005             3318.0             3848.0
# 4           4     1006             2612.0             1127.0
#
#    Multi core score3  Multi core score4  Memory1  Memory2  Memory3  Memory4  \
# 0             1525.0             2281.0     3.62     3.64     3.73     5.74
# 1              857.0             1326.0     2.00     2.00     2.00     1.00
# 2             2474.0             1643.0     1.00     2.00     1.00     1.00
# 3             3610.0             4071.0    15.52     1.00     1.00     1.00
# 4             2252.0             5887.0     1.00     1.00     1.00     2.00
#
#    Geekbench_score
# 0           2281.0
# 1           3394.0
# 2           6647.0
# 3           4071.0
# 4           5887.0

# %%
pc_details['RAM'] = pc_details[['Memory1', 'Memory2', 'Memory3', 'Memory4']].values.max(1)

# %%
pc_details.head()
# Out:
#    Unnamed: 0  team_id  Multi core score1  Multi core score2  \
# 0           0     1001             2148.0             1132.0
# 1           1     1002             3394.0             1834.0
# 2           2     1004             2303.0             6647.0
# 3           3     1005             3318.0             3848.0
# 4           4     1006             2612.0             1127.0
#
#    Multi core score3  Multi core score4  Memory1  Memory2  Memory3  Memory4  \
# 0             1525.0             2281.0     3.62     3.64     3.73     5.74
# 1              857.0             1326.0     2.00     2.00     2.00     1.00
# 2             2474.0             1643.0     1.00     2.00     1.00     1.00
# 3             3610.0             4071.0    15.52     1.00     1.00     1.00
# 4             2252.0             5887.0     1.00     1.00     1.00     2.00
#
#    Geekbench_score    RAM
# 0           2281.0   5.74
# 1           3394.0   2.00
# 2           6647.0   2.00
# 3           4071.0  15.52
# ...

# %% [markdown]
# **Note :** The columns Geekbench score and RAM correspond to maximum values in Multi core score and Memory. But if they are from pcs of different individuals there will be a mismatch. To handle this case, two other columns indicating max geekbench score and RAM of same pc are created.

# %%
pc_details1 = pc_details.drop(['Multi core score1', 'Multi core score2', 'Multi core score3','Multi core score4', 'Memory1', 'Memory2', 'Memory3', 'Memory4', 'Unnamed: 0'], axis=1)
pc_details1.head()
# Out:
#    team_id  Geekbench_score    RAM
# 0     1001           2281.0   5.74
# 1     1002           3394.0   2.00
# 2     1004           6647.0   2.00
# 3     1005           4071.0  15.52
# 4     1006           5887.0   2.00

# %%
pc_details1.to_csv('Gb_score_RAM_Max_values.csv', index=False)
