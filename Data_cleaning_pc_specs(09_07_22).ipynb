# %% [markdown]
# <a href="https://colab.research.google.com/github/adityapanwar94/Data-Analysis-and-Process-Automation-DaPrA-/blob/harshini/Data_cleaning_pc_specs(09_07_22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Import Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %%
pc_details = pd.read_csv(r'/content/drive/MyDrive/dataset/Cleaned_pc_specs3.csv')
pc_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1293 non-null   int64
#  1   team_id             1293 non-null   int64
#  2   Single core score1  1293 non-null   object
#  3   Single core score2  1293 non-null   object
#  4   Single core score3  1293 non-null   object
#  5   Single core score4  1293 non-null   object
#  6   Multi core score1   1293 non-null   object
#  7   Multi core score2   1293 non-null   object
#  8   Multi core score3   1293 non-null   object
#  9   Multi core score4   1293 non-null   object
#  10  OpenCL score1       959 non-null    object
#  11  OpenCL score2       883 non-null    object
#  12  OpenCL score3       859 non-null    object
#  13  OpenCL score4       848 non-null    object
#  14  OS1                 1293 non-null   object
# ...

# %%
pc_details.head()
# Out:
#    Unnamed: 0  team_id Single core score1 Single core score2  \
# 0           0     1001               1142                543
# 1           1     1002               1060                549
# 2           2     1004                809               1182
# 3           3     1005                686               1003
# 4           4     1006               1004                422
#
#   Single core score3 Single core score4 Multi core score1 Multi core score2  \
# 0                836                601              2148              1132
# 1                416                590              3394              1834
# 2                847                770              2303              6647
# 3                624                827              3318              3848
# 4                657               1121              2612              1127
#
#   Multi core score3 Multi core score4  ...                  CPU3  \
# 0              1525              2281  ...   Intel Core i5-7200U
# ...

# %% [markdown]
# ## **Analzing the values and count of numeric values**

# %%
pc_details['Memory1'].str.isnumeric().sum()
# Out:
# 973

# %%
import re

# %%
pc_details['Memory1'].str.isalpha().sum()
# Out:
# 214

# %%
pc_details['Memory2'].str.isalpha().sum()
# Out:
# 308

# %%
pc_details['Memory3'].str.isalpha().sum()
# Out:
# 313

# %%
pc_details['Memory1']
# Out:
# 0        3.62
# 1             2
# 2             1
# 3       15.52
# 4             1
#          ...
# 1288          1
# 1289          2
# 1290        Nil
# 1291        Nil
# 1292        Nil
# Name: Memory1, Length: 1293, dtype: object

# %%
pc_details['Memory1'].isnull().sum()
# Out:
# 0

# %%
pc_details['Memory1'].str.replace('Nil','')
# Out:
# 0        3.62
# 1             2
# 2             1
# 3       15.52
# 4             1
#          ...
# 1288          1
# 1289          2
# 1290
# 1291
# 1292
# Name: Memory1, Length: 1293, dtype: object

# %%
pc_details['Memory1'].isnull().sum()
# Out:
# 0

# %%
a=  pc_details['Memory1'].unique()
print(a)
# Out:
# ['3.62  ' '2' '1' '15.52  ' '8.00   LPDDR3 2133 MT/s' '7.69  ' '7.60  '
#  '15.30  ' 'Nil' '5.74  ' '7.77  ' '7.68  ' '7.67  ' '15.51  ' '3.76  '
#  '4.00    794 MHz' '8.00  ' '7.56  ' '3.86  ' '16.00  ' '11.58  ' '1.95  '
#  '16.00   LPDDR4X 3733 MT/s' '7.62  ' '7.66  ' '4' '7.55  '
#  '3.92   DDR3 SDRAM 1599 MHz' '15.57  ' '7.85  ' '3.30  ' '3.63  '
#  '4.00   DDR3 SDRAM 665 MHz' '7.64  ' '6.75  ' '8.00   LPDDR4X 3733 MT/s'
#  '8.00   DDR3 1600 MT/s' '15.37  ' '8.00   LPDDR3 933 MHz' '3.74  '
#  '3.55  ' '15.14  ' '3.71  ' '7.14  ' '4.00   DDR3 SDRAM 1599 MHz'
#  '7.86  ' '3.75  ' '7.44  ' '3.69  ' '7.63  ' '15.39  ' '4.00  ' '11.49  '
#  '15.55  ' '15.49  ' '7.65  ' '4.00    798 MHz' '16.00   EDO RAM' '7.52  ']

# %%
print(pc_details.isna().sum().sort_values(ascending=False).to_markdown())
# Out:
# |                    |   0 |
# |:-------------------|----:|
# | Graphic Card4      | 445 |
# | OpenCL score4      | 445 |
# | OpenCL score3      | 434 |
# | Graphic Card3      | 434 |
# | Graphic Card2      | 410 |
# | OpenCL score2      | 410 |
# | Graphic Card1      | 334 |
# | OpenCL score1      | 334 |
# | Model4             |   0 |
# | CPU1               |   0 |
# | CPU2               |   0 |
# | CPU3               |   0 |
# | CPU4               |   0 |
# | Model2             |   0 |
# | Memory1            |   0 |
# | Memory2            |   0 |
# | Memory3            |   0 |
# | Memory4            |   0 |
# | Model3             |   0 |
# | Unnamed: 0         |   0 |
# | Model1             |   0 |
# | team_id            |   0 |
# | OS3                |   0 |
# | OS2                |   0 |
# | OS1                |   0 |
# | Multi core score4  |   0 |
# | Multi core score3  |   0 |
# | Multi core score2  |   0 |
# | Multi core score1  |   0 |
# | Single core score4 |   0 |
# ...

# %%
pc_details.columns
# Out:
# Index(['Unnamed: 0', 'team_id', 'Single core score1', 'Single core score2',
#        'Single core score3', 'Single core score4', 'Multi core score1',
#        'Multi core score2', 'Multi core score3', 'Multi core score4',
#        'OpenCL score1', 'OpenCL score2', 'OpenCL score3', 'OpenCL score4',
#        'OS1', 'OS2', 'OS3', 'OS4', 'Model1', 'Model2', 'Model3', 'Model4',
#        'CPU1', 'CPU2', 'CPU3', 'CPU4', 'Memory1', 'Memory2', 'Memory3',
#        'Memory4', 'Graphic Card1', 'Graphic Card2', 'Graphic Card3',
#        'Graphic Card4'],
#       dtype='object')

# %%
print(pc_details.isnull().sum(axis=1).sort_values(ascending=False).to_markdown())
# Out:
# |      |   0 |
# |-----:|----:|
# | 1292 |   8 |
# |  133 |   8 |
# |  837 |   8 |
# | 1137 |   8 |
# | 1136 |   8 |
# | 1135 |   8 |
# | 1134 |   8 |
# | 1133 |   8 |
# | 1132 |   8 |
# | 1131 |   8 |
# |  843 |   8 |
# | 1141 |   8 |
# |  370 |   8 |
# |  861 |   8 |
# | 1127 |   8 |
# | 1126 |   8 |
# | 1124 |   8 |
# | 1122 |   8 |
# | 1121 |   8 |
# |  143 |   8 |
# |  387 |   8 |
# |  392 |   8 |
# |  145 |   8 |
# |  437 |   8 |
# |  772 |   8 |
# |  775 |   8 |
# | 1185 |   8 |
# |   94 |   8 |
# | 1184 |   8 |
# |  439 |   8 |
# | 1180 |   8 |
# | 1178 |   8 |
# |  790 |   8 |
# |  406 |   8 |
# |  806 |   8 |
# | 1166 |   8 |
# |  419 |   8 |
# | 1038 |   8 |
# |  812 |   8 |
# |  815 |   8 |
# | 1159 |   8 |
# |  816 |   8 |
# | 1120 |   8 |
# | 1119 |   8 |
# |  762 |   8 |
# |  245 |   8 |
# |  264 |   8 |
# |  984 |   8 |
# |  989 |   8 |
# | 1069 |   8 |
# |  994 |   8 |
# | 1066 |   8 |
# | 1065 |   8 |
# |  997 |   8 |
# | 1060 |   8 |
# | 1079 |   8 |
# ...

# %%
Nullvalsgrouped = pd.DataFrame(pc_details.isnull().sum(axis=1).sort_values(ascending=False))

# %%
Nullvalsgrouped[Nullvalsgrouped[0]>15].index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# **Observation**: These are the teams with more than 15 null values, but there can be pc facilites with atleast one of the members in the team, so we need not drop these teams.

# %% [markdown]
# ## **Managing null values in Memory column**

# %%
Memory1_null = pd.DataFrame(pc_details.Memory1.isnull())
Memory2_null = pd.DataFrame(pc_details.Memory2.isnull())
Memory3_null = pd.DataFrame(pc_details.Memory3.isnull())
Memory4_null = pd.DataFrame(pc_details.Memory4.isnull())

# %%
pc_details['Memory1'] = pc_details['Memory1'].fillna(0)

# %%
pc_details['Memory2'] = pc_details['Memory2'].fillna(0)

# %%
pc_details[pc_details['Memory1'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, team_id, Single core score1, Single core score2, Single core score3, Single core score4, Multi core score1, Multi core score2, Multi core score3, Multi core score4, OpenCL score1, OpenCL score2, OpenCL score3, OpenCL score4, OS1, OS2, OS3, OS4, Model1, Model2, Model3, Model4, CPU1, CPU2, CPU3, CPU4, Memory1, Memory2, Memory3, Memory4, Graphic Card1, Graphic Card2, Graphic Card3, Graphic Card4]
# Index: []
#
# [0 rows x 34 columns]

# %%
print(pc_details.isna().sum().sort_values(ascending=False).to_markdown())
# Out:
# |                    |   0 |
# |:-------------------|----:|
# | Graphic Card4      | 445 |
# | OpenCL score4      | 445 |
# | OpenCL score3      | 434 |
# | Graphic Card3      | 434 |
# | Graphic Card2      | 410 |
# | OpenCL score2      | 410 |
# | Graphic Card1      | 334 |
# | OpenCL score1      | 334 |
# | Model4             |   0 |
# | CPU1               |   0 |
# | CPU2               |   0 |
# | CPU3               |   0 |
# | CPU4               |   0 |
# | Model2             |   0 |
# | Memory1            |   0 |
# | Memory2            |   0 |
# | Memory3            |   0 |
# | Memory4            |   0 |
# | Model3             |   0 |
# | Unnamed: 0         |   0 |
# | Model1             |   0 |
# | team_id            |   0 |
# | OS3                |   0 |
# | OS2                |   0 |
# | OS1                |   0 |
# | Multi core score4  |   0 |
# | Multi core score3  |   0 |
# | Multi core score2  |   0 |
# | Multi core score1  |   0 |
# | Single core score4 |   0 |
# ...

# %% [markdown]
# ## **Managing null values in score column**

# %%
pc_details['Single core score1'] = pc_details['Single core score1'].fillna(0)
pc_details['Single core score2'] = pc_details['Single core score2'].fillna(0)
pc_details['Single core score3'] = pc_details['Single core score3'].fillna(0)
pc_details['Single core score4'] = pc_details['Single core score4'].fillna(0)

# %%
pc_details[pc_details['Single core score1'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, team_id, Single core score1, Single core score2, Single core score3, Single core score4, Multi core score1, Multi core score2, Multi core score3, Multi core score4, OpenCL score1, OpenCL score2, OpenCL score3, OpenCL score4, OS1, OS2, OS3, OS4, Model1, Model2, Model3, Model4, CPU1, CPU2, CPU3, CPU4, Memory1, Memory2, Memory3, Memory4, Graphic Card1, Graphic Card2, Graphic Card3, Graphic Card4]
# Index: []
#
# [0 rows x 34 columns]

# %%
print(pc_details.isna().sum().sort_values(ascending=False).to_markdown())
# Out:
# |                    |   0 |
# |:-------------------|----:|
# | Graphic Card4      | 445 |
# | OpenCL score4      | 445 |
# | OpenCL score3      | 434 |
# | Graphic Card3      | 434 |
# | Graphic Card2      | 410 |
# | OpenCL score2      | 410 |
# | Graphic Card1      | 334 |
# | OpenCL score1      | 334 |
# | Model4             |   0 |
# | CPU1               |   0 |
# | CPU2               |   0 |
# | CPU3               |   0 |
# | CPU4               |   0 |
# | Model2             |   0 |
# | Memory1            |   0 |
# | Memory2            |   0 |
# | Memory3            |   0 |
# | Memory4            |   0 |
# | Model3             |   0 |
# | Unnamed: 0         |   0 |
# | Model1             |   0 |
# | team_id            |   0 |
# | OS3                |   0 |
# | OS2                |   0 |
# | OS1                |   0 |
# | Multi core score4  |   0 |
# | Multi core score3  |   0 |
# | Multi core score2  |   0 |
# | Multi core score1  |   0 |
# | Single core score4 |   0 |
# ...

# %%
pc_details.fillna(value=0, inplace=True)

# %%
print(pc_details.isna().sum().sort_values(ascending=False).to_markdown())
# Out:
# |                    |   0 |
# |:-------------------|----:|
# | Unnamed: 0         |   0 |
# | CPU4               |   0 |
# | Model2             |   0 |
# | Model3             |   0 |
# | Model4             |   0 |
# | CPU1               |   0 |
# | CPU2               |   0 |
# | CPU3               |   0 |
# | Memory1            |   0 |
# | team_id            |   0 |
# | Memory2            |   0 |
# | Memory3            |   0 |
# | Memory4            |   0 |
# | Graphic Card1      |   0 |
# | Graphic Card2      |   0 |
# | Graphic Card3      |   0 |
# | Model1             |   0 |
# | OS4                |   0 |
# | OS3                |   0 |
# | OS2                |   0 |
# | OS1                |   0 |
# | OpenCL score4      |   0 |
# | OpenCL score3      |   0 |
# | OpenCL score2      |   0 |
# | OpenCL score1      |   0 |
# | Multi core score4  |   0 |
# | Multi core score3  |   0 |
# | Multi core score2  |   0 |
# | Multi core score1  |   0 |
# | Single core score4 |   0 |
# ...

# %%
pc_details
# Out:
#       Unnamed: 0  team_id Single core score1 Single core score2  \
# 0              0     1001               1142                543
# 1              1     1002               1060                549
# 2              2     1004                809               1182
# 3              3     1005                686               1003
# 4              4     1006               1004                422
# ...          ...      ...                ...                ...
# 1288        1288     2964                416                777
# 1289        1289     2965                664                Nil
# 1290        1290     2968                Nil                Nil
# 1291        1291     2970                Nil                Nil
# 1292        1292     2971                Nil                Nil
#
#      Single core score3 Single core score4 Multi core score1  \
# 0                   836                601              2148
# 1                   416                590              3394
# ...

# %% [markdown]
# ## **Cleaning and normalizing Memory columns**

# %%
pc_details['Memory1'].str.isalpha().sum()
# Out:
# 214

# %%
a=  pc_details['Memory1'].unique()
print(a)
# Out:
# ['3.62  ' '2' '1' '15.52  ' '8.00   LPDDR3 2133 MT/s' '7.69  ' '7.60  '
#  '15.30  ' 'Nil' '5.74  ' '7.77  ' '7.68  ' '7.67  ' '15.51  ' '3.76  '
#  '4.00    794 MHz' '8.00  ' '7.56  ' '3.86  ' '16.00  ' '11.58  ' '1.95  '
#  '16.00   LPDDR4X 3733 MT/s' '7.62  ' '7.66  ' '4' '7.55  '
#  '3.92   DDR3 SDRAM 1599 MHz' '15.57  ' '7.85  ' '3.30  ' '3.63  '
#  '4.00   DDR3 SDRAM 665 MHz' '7.64  ' '6.75  ' '8.00   LPDDR4X 3733 MT/s'
#  '8.00   DDR3 1600 MT/s' '15.37  ' '8.00   LPDDR3 933 MHz' '3.74  '
#  '3.55  ' '15.14  ' '3.71  ' '7.14  ' '4.00   DDR3 SDRAM 1599 MHz'
#  '7.86  ' '3.75  ' '7.44  ' '3.69  ' '7.63  ' '15.39  ' '4.00  ' '11.49  '
#  '15.55  ' '15.49  ' '7.65  ' '4.00    798 MHz' '16.00   EDO RAM' '7.52  ']

# %%
columns = ['Memory1', 'Memory2', 'Memory3', 'Memory4']

def Memory_replace(columns):  # Removing text data
  for cols in columns:
    pc_details[cols] = pc_details[cols].str.split(' ').str[0]
  return pc_details

pc_details = Memory_replace(columns)

# %%
a=  pc_details['Memory1'].unique()
print(a)
# Out:
# ['3.62' '2' '1' '15.52' '8.00' '7.69' '7.60' '15.30' 'Nil' '5.74' '7.77'
#  '7.68' '7.67' '15.51' '3.76' '4.00' '7.56' '3.86' '16.00' '11.58' '1.95'
#  '7.62' '7.66' '4' '7.55' '3.92' '15.57' '7.85' '3.30' '3.63' '7.64'
#  '6.75' '15.37' '3.74' '3.55' '15.14' '3.71' '7.14' '7.86' '3.75' '7.44'
#  '3.69' '7.63' '15.39' '11.49' '15.55' '15.49' '7.65' '7.52']

# %%
columns = ['Memory1', 'Memory2', 'Memory3', 'Memory4']

def Memory_null_replace(columns):   # Converting nil and null values to 0
  for cols in columns:
    pc_details[cols] = pc_details[cols].replace('Nil' , '')
    pc_details[cols] = pc_details[cols].replace(r'^\s*$', np.nan, regex=True)  # Converting null values(empty string) to NaN
    pc_details[cols] = pc_details[cols].fillna(0)     # Replace all NaN with 0
  return pc_details

pc_details = Memory_null_replace(columns)

# %%
pc_details
# Out:
#       Unnamed: 0  team_id Single core score1 Single core score2  \
# 0              0     1001               1142                543
# 1              1     1002               1060                549
# 2              2     1004                809               1182
# 3              3     1005                686               1003
# 4              4     1006               1004                422
# ...          ...      ...                ...                ...
# 1288        1288     2964                416                777
# 1289        1289     2965                664                Nil
# 1290        1290     2968                Nil                Nil
# 1291        1291     2970                Nil                Nil
# 1292        1292     2971                Nil                Nil
#
#      Single core score3 Single core score4 Multi core score1  \
# 0                   836                601              2148
# 1                   416                590              3394
# ...

# %%
a = pc_details['Memory1'].unique()
print(a)
# Out:
# ['3.62' '2' '1' '15.52' '8.00' '7.69' '7.60' '15.30' 0 '5.74' '7.77'
#  '7.68' '7.67' '15.51' '3.76' '4.00' '7.56' '3.86' '16.00' '11.58' '1.95'
#  '7.62' '7.66' '4' '7.55' '3.92' '15.57' '7.85' '3.30' '3.63' '7.64'
#  '6.75' '15.37' '3.74' '3.55' '15.14' '3.71' '7.14' '7.86' '3.75' '7.44'
#  '3.69' '7.63' '15.39' '11.49' '15.55' '15.49' '7.65' '7.52']

# %%
a = pc_details['Memory2'].unique()
print(a)
# Out:
# ['3.64' '2' '1' '3.62' '15.29' '15.49' 0 '8.00' '5.81' '7.21' '5.71'
#  '16.00' '7.67' '7.68' '13.64' '7.58' '7.55' '15.43' '3.51' '15.65' '3.75'
#  '11.58' '3.86' '7.69' '4.00' '7.64' '3.73' '7.62' '3.76' '7.47' '7.60'
#  '7.50' '19.23' '7.54' '3.65' '5.77' '3.88' '3.68' '15.32' '3.54' '12.00'
#  '11.59' '15.46' '15.57' '1.96' '32.00']

# %%
a = pc_details['Memory3'].unique()
print(a)
# Out:
# ['3.73' '2' '1' '4.00' '15.52' '7.68' '19.46' 0 '15.56' '7.65' '7.71'
#  '8.00' '16.00' '3.32' '7.88' '7.55' '5.70' '7.61' '7.64' '5.73' '7.21'
#  '7.46' '3.55' '3.72' '3.35' '7.58' '7.70' '15.51' '7.56' '3.91' '3.76'
#  '4' '32.00' '7.69' '3.85' '7.66' '7.60' '3.88']

# %%
a = pc_details['Memory4'].unique()
print(a)
# Out:
# ['5.74' '1' '2' '7.65' '7.85' 0 '8.00' '16.00' '15.48' '7.56' '7.78'
#  '7.52' '7.66' '7.70' '15.52' '15.51' '7.63' '7.61' '4.00' '4' '32.00'
#  '3.74' '15.56' '7.44' '15.36' '11.81' '11.54' '3.57' '11.48' '7.60'
#  '15.53' '11.86']

# %% [markdown]
# **Observation :** The unique values listed here shows that all string data were removed from memory columns and the data is normalized.

# %% [markdown]
# ## **Analysing score data**

# %%
a = pc_details['Single core score1'].unique()
print(a)
# Out:
# ['1142' '1060' '809' '686' '1004' '834' '973' '769' '1044' '1150' '493'
#  '632' '805' '325' '855' '1057' '1114' '1096' '794' '815' '545' '860'
#  '1186' '967' '551' '1291' '1048' '1015' '980' '765' '323' '569' '522'
#  'Nil' '1140' '521' '348' '603' '917' '1054' '820' '1066' '464' '1086'
#  '747' '1128' '911' '777' '892' '1031' '783' '657' '934' '811' '665' '417'
#  '454' '1233' '607' '975' '758' '1136' '652' '253' '1132' '902' '432'
#  '888' '1078' '912' '1047' '289' '1062' '451' '1359' '455' '816' '974'
#  '969' '1009' '466' '990' '713' '703' '1162' '343' '706' '599' '398'
#  '1104' '971' '585' '874' '535' '276' '957' '1107' '460' '913' '463' '675'
#  '985' '1038' '1052' '1039' '1181' '486' '1241' '523' '536' '528' '505'
#  '359' '767' '882' '354' '618' '732' '407' '839' '890' '234' '1063' '1274'
#  '899' '550' '1073' '1007' '1203' '1072' '992' '502' '986' '1018' '633'
#  '563' '879' '548' '895' '875' '634' '339' '396' '952' '223' '869' '734'
# ...

# %% [markdown]
# The score data are all clean and do not consist of null values, these values should be converted to integer format.

# %% [markdown]
# ## **Converting score and memory column to numeric format**

# %%
pc_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1293 non-null   int64
#  1   team_id             1293 non-null   int64
#  2   Single core score1  1293 non-null   object
#  3   Single core score2  1293 non-null   object
#  4   Single core score3  1293 non-null   object
#  5   Single core score4  1293 non-null   object
#  6   Multi core score1   1293 non-null   object
#  7   Multi core score2   1293 non-null   object
#  8   Multi core score3   1293 non-null   object
#  9   Multi core score4   1293 non-null   object
#  10  OpenCL score1       1293 non-null   object
#  11  OpenCL score2       1293 non-null   object
#  12  OpenCL score3       1293 non-null   object
#  13  OpenCL score4       1293 non-null   object
#  14  OS1                 1293 non-null   object
# ...

# %%
columns = ['Single core score1', 'Single core score2', 'Single core score3', 'Single core score4', 'Multi core score1', 'Multi core score2', 'Multi core score3', 'Multi core score4', 'Memory1', 'Memory2', 'Memory3', 'Memory4']
def Convert_to_numerical(columns):
  for cols in columns:
    pc_details[cols] = pc_details[cols].apply(pd.to_numeric, errors='coerce')
  return pc_details

pc_details = Convert_to_numerical(columns)

# %%
pc_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1293 non-null   int64
#  1   team_id             1293 non-null   int64
#  2   Single core score1  1059 non-null   float64
#  3   Single core score2  963 non-null    float64
#  4   Single core score3  954 non-null    float64
#  5   Single core score4  933 non-null    float64
#  6   Multi core score1   1059 non-null   float64
#  7   Multi core score2   963 non-null    float64
#  8   Multi core score3   954 non-null    float64
#  9   Multi core score4   933 non-null    float64
#  10  OpenCL score1       1293 non-null   object
#  11  OpenCL score2       1293 non-null   object
#  12  OpenCL score3       1293 non-null   object
#  13  OpenCL score4       1293 non-null   object
#  14  OS1                 1293 non-null   object
# ...

# %%
a = pc_details['Memory1'].unique()
print(a) # Check with one column
# Out:
# [ 3.62  2.    1.   15.52  8.    7.69  7.6  15.3   0.    5.74  7.77  7.68
#   7.67 15.51  3.76  4.    7.56  3.86 16.   11.58  1.95  7.62  7.66  7.55
#   3.92 15.57  7.85  3.3   3.63  7.64  6.75 15.37  3.74  3.55 15.14  3.71
#   7.14  7.86  3.75  7.44  3.69  7.63 15.39 11.49 15.55 15.49  7.65  7.52]

# %% [markdown]
# **Observation :** All the score and memory columns have been converted to numeric format, so mean or average of these values can be calculated.

# %% [markdown]
# ## **Analzing other columns**

# %%
a = pc_details['CPU1'].unique()
print(a)
# Out:
# ['Intel Core i3-1005G1' 'Intel Core i7-9750H' 'Intel Core i7-8565U'
#  'Intel Core i5-10300H' 'Intel Core i7-8750H' 'Intel Core i5-1135G7'
#  'AMD Ryzen 5 2500U' 'Intel Core i5-8300H' 'Intel Core i5-1035G1'
#  'Intel Core i5-8265U' 'Intel Core i5-8210Y' 'Intel Core i5-8250U'
#  'AMD Ryzen 5 5500U' 'Intel Core i5-7200U' 'Intel Core i5-5200U'
#  'Intel Core i5-1035G4' 'Intel Core i7-7700HQ' 'Intel Core i3-7020U'
#  'Intel Core i7-10750H' 'Intel Core i5-10210U' 'AMD Ryzen 5 3550H'
#  'Intel Core i3-380M' 'Intel Core i5-6200U' 'Intel Core i5-9300HF' 'Nil'
#  'ASUSTeK COMPUTER INC. X409JB' 'AMD Ryzen 7 3750H' 'Intel Core i5-520M'
#  'AMD Ryzen 3 3200U' 'AMD Ryzen 5 3500U' 'Intel Core i5-8259U'
#  'Intel Core i5-6402P' 'AMD Ryzen 5 2600' 'AMD Ryzen 3 3250U' 'HP 8742'
#  'AMD Ryzen 5 4600H' 'Intel Core i3-7100' 'ASUSTeK COMPUTER INC. X513EA'
#  'Intel Core i5-5350U' 'Intel Core i5-3320M' 'Intel Core i5-4570'
#  'LENOVO LNVNB161216' 'Intel Core i3-7100U' 'Dell Inc. 0NV0M7'
# ...

# %%
a = pc_details['Graphic Card1'].unique()
print(a)
# Out:
# [0 '3.14  ' '2.00   3.00  ' '4.00  ' '2.00  ' '4.92  ' '3.11  ' '1.50  '
#  '1.55  ' 'GeForce GTX 1650' '6.37  ' '3.12  ' '3.82  ' '3.95  ' '3.15  '
#  '6.00  ' '5.52  ' 'AMD RADV RAVEN (ACO)' '3.00  '
#  'AMD RADV POLARIS11 (ACO)' '4.02  ' '1.56  ' '3.08  ' '1.37  '
#  '1.95   800 MHz' 'Nil' '1.96   2.50  ' '1.57  ' '1.00 MB x 1' '4.71  '
#  '4.04  ' '1.52  ' '3.10  ' '3.16  ' '3.13  ' '1.59  ' '6.36  '
#  'AMD Radeon (TM) R5 M430' '3.09  ' '3.06  ' '6.27  ' '4.03  ' '1.54  '
#  '1.23  ' 'Apple M1' '3.17  ' '2.00   5.00  ' '1.38  ' '1.22  ' '4.76  '
#  '6.08  ' '12.4  ' '2.33  ' 'Intel(R) Iris(R) Xe Graphics' '8.00  '
#  '5.33  ' '6.07  ' '4.00   6.00  ' '7.04  ' '3.42  ' '5.80  '
#  '3.00 MB x 1' '6.31  ' '1.61  ' '1.62  ' '1.96  ' '1.24  '
#  '6.00   6.00  ' '3.99  ' '3.98  ' '2.97  ' '6.33  ' '6.34  '
#  '1.96   3.50  ' '6.00   7.00  ' '1.32  ' '1.02  ' '3.04  ' '3.41  '
#  '1.39  ' '5.54  ' '3.02  ' '4.74  ' '3.81  ' '1.53  ' '6.32  '
# ...

# %% [markdown]
# ## **Cleaning Graphic card details**

# %%
columns = ['Graphic Card1', 'Graphic Card2', 'Graphic Card3', 'Graphic Card4']

def Graphic_card_replace(columns):        # Removing text data
  for cols in columns:
    pc_details[cols] = pc_details[cols].str.split(' ').str[0]   # Only first part of the strings is retained
  return pc_details

pc_details = Graphic_card_replace(columns)

# %%
a = pc_details['Graphic Card1'].unique()
print(a)
# Out:
# [nan '3.14' '2.00' '4.00' '4.92' '3.11' '1.50' '1.55' 'GeForce' '6.37'
#  '3.12' '3.82' '3.95' '3.15' '6.00' '5.52' 'AMD' '3.00' '4.02' '1.56'
#  '3.08' '1.37' '1.95' 'Nil' '1.96' '1.57' '1.00' '4.71' '4.04' '1.52'
#  '3.10' '3.16' '3.13' '1.59' '6.36' '3.09' '3.06' '6.27' '4.03' '1.54'
#  '1.23' 'Apple' '3.17' '1.38' '1.22' '4.76' '6.08' '12.4' '2.33'
#  'Intel(R)' '8.00' '5.33' '6.07' '7.04' '3.42' '5.80' '6.31' '1.61' '1.62'
#  '1.24' '3.99' '3.98' '2.97' '6.33' '6.34' '1.32' '1.02' '3.04' '3.41'
#  '1.39' '5.54' '3.02' '4.74' '3.81' '1.53' '6.32' '3.72' '1.34' '2.36'
#  '12.0' '7.01' '1.49' '1.51' '4.77' '4.73' '6.35' '6.30' '6.29' '3.07'
#  '6.28' 'Radeon' '512' '1.94']

# %%
columns = ['Graphic Card1', 'Graphic Card2', 'Graphic Card3', 'Graphic Card4']

def Graphic_null_replace(columns):   # Converting nil and null values to 0 and replacing text data
  for cols in columns:
    pc_details[cols] = pc_details[cols].replace('Nil' , '')
    pc_details[cols] = pc_details[cols].apply(pd.to_numeric,errors='coerce') # Replace text data with NaN
    pc_details[cols] = pc_details[cols].fillna(0)
  return pc_details

pc_details = Graphic_null_replace(columns)

# %%
pc_details.head()
# Out:
#    Unnamed: 0  team_id  Single core score1  Single core score2  \
# 0           0     1001              1142.0               543.0
# 1           1     1002              1060.0               549.0
# 2           2     1004               809.0              1182.0
# 3           3     1005               686.0              1003.0
# 4           4     1006              1004.0               422.0
#
#    Single core score3  Single core score4  Multi core score1  \
# 0               836.0               601.0             2148.0
# 1               416.0               590.0             3394.0
# 2               847.0               770.0             2303.0
# 3               624.0               827.0             3318.0
# 4               657.0              1121.0             2612.0
#
#    Multi core score2  Multi core score3  Multi core score4  ...  \
# 0             1132.0             1525.0             2281.0  ...
# 1             1834.0              857.0             1326.0  ...
# ...

# %%
a = pc_details['Graphic Card1'].unique()
print(a)
# Out:
# [  0.     3.14   2.     4.     4.92   3.11   1.5    1.55   6.37   3.12
#    3.82   3.95   3.15   6.     5.52   3.     4.02   1.56   3.08   1.37
#    1.95   1.96   1.57   1.     4.71   4.04   1.52   3.1    3.16   3.13
#    1.59   6.36   3.09   3.06   6.27   4.03   1.54   1.23   3.17   1.38
#    1.22   4.76   6.08  12.4    2.33   8.     5.33   6.07   7.04   3.42
#    5.8    6.31   1.61   1.62   1.24   3.99   3.98   2.97   6.33   6.34
#    1.32   1.02   3.04   3.41   1.39   5.54   3.02   4.74   3.81   1.53
#    6.32   3.72   1.34   2.36  12.     7.01   1.49   1.51   4.77   4.73
#    6.35   6.3    6.29   3.07   6.28 512.     1.94]

# %%
pc_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1293 non-null   int64
#  1   team_id             1293 non-null   int64
#  2   Single core score1  1059 non-null   float64
#  3   Single core score2  963 non-null    float64
#  4   Single core score3  954 non-null    float64
#  5   Single core score4  933 non-null    float64
#  6   Multi core score1   1059 non-null   float64
#  7   Multi core score2   963 non-null    float64
#  8   Multi core score3   954 non-null    float64
#  9   Multi core score4   933 non-null    float64
#  10  OpenCL score1       1293 non-null   object
#  11  OpenCL score2       1293 non-null   object
#  12  OpenCL score3       1293 non-null   object
#  13  OpenCL score4       1293 non-null   object
#  14  OS1                 1293 non-null   object
# ...

# %% [markdown]
# ## **Cleaning opencl score data**

# %%
a = pc_details['OpenCL score1'].unique()
print(a)
# Out:
# [0 '5735' '8153' '43776' '22699' '15354' '8557' '19103' '5105' '5490'
#  '4186' '4544' '8067' '7211' '36957' '41394' '44790' '4842' '2399' '7019'
#  '37313' '4584' '27873' '13309' '5595' '4892' '41529' '35789' '24786'
#  '5011' '40468' '2865' '7712' '21091' '40788' '11508' '5031' '5032'
#  '46325' '22837' '42054' '39447' '41428' '4345' '4925' '9954' '1057'
#  '1377' '40324' '10869' 'Nil' '2538' '10165' '6532' '4101' '39536' '38928'
#  '11135' '256' '8765' '5245' '9600' '43970' '33986' '38115' '781' '37535'
#  '3126' '10303' '70560' '7312' '4690' '5827' '3334' '35415' '47176'
#  '33412' '7055' '4908' '37793' '4502' '3539' '7277' '2799' '38483' '35510'
#  '11499' '36002' '4894' '2983' '18375' '51342' '18783' '22747' '4323'
#  '3531' '8728' '38344' '8646' '11317' '44999' '2740' '11262' '4865' '4133'
#  '7615' '15335' '8943' '10933' '11531' '4300' '2508' '4527' '3133' '9072'
#  '44883' '5040' '6986' '5424' '60379' '3221' '41113' '9663' '7503' '71675'
# ...

# %%
columns = ['OpenCL score1', 'OpenCL score2', 'OpenCL score3', 'OpenCL score4']

def Opencl_clean(columns):   # Converting nil and null values to 0 and replacing text data
  for cols in columns:
    pc_details[cols] = pc_details[cols].replace('Nil' , '')
    pc_details[cols] = pc_details[cols].apply(pd.to_numeric,errors='coerce') # Replace text data with NaN
    pc_details[cols] = pc_details[cols].fillna(0)
  return pc_details

pc_details = Opencl_clean(columns)

# %%
pc_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1293 non-null   int64
#  1   team_id             1293 non-null   int64
#  2   Single core score1  1059 non-null   float64
#  3   Single core score2  963 non-null    float64
#  4   Single core score3  954 non-null    float64
#  5   Single core score4  933 non-null    float64
#  6   Multi core score1   1059 non-null   float64
#  7   Multi core score2   963 non-null    float64
#  8   Multi core score3   954 non-null    float64
#  9   Multi core score4   933 non-null    float64
#  10  OpenCL score1       1293 non-null   float64
#  11  OpenCL score2       1293 non-null   float64
#  12  OpenCL score3       1293 non-null   float64
#  13  OpenCL score4       1293 non-null   float64
#  14  OS1                 1293 non-null   object
# ...

# %% [markdown]
# Now we can see that only OS, CPU and Model are in Text format all other data are in numeric format

# %%
print(pc_details.isna().sum().sort_values(ascending=False).to_markdown())
# Out:
# |                    |   0 |
# |:-------------------|----:|
# | Single core score4 | 360 |
# | Multi core score4  | 360 |
# | Single core score3 | 339 |
# | Multi core score3  | 339 |
# | Single core score2 | 330 |
# | Multi core score2  | 330 |
# | Single core score1 | 234 |
# | Multi core score1  | 234 |
# | Unnamed: 0         |   0 |
# | Memory2            |   0 |
# | CPU2               |   0 |
# | CPU3               |   0 |
# | CPU4               |   0 |
# | Memory1            |   0 |
# | Graphic Card3      |   0 |
# | Memory3            |   0 |
# | Memory4            |   0 |
# | Graphic Card1      |   0 |
# | Graphic Card2      |   0 |
# | Model4             |   0 |
# | CPU1               |   0 |
# | OS4                |   0 |
# | Model3             |   0 |
# | Model2             |   0 |
# | Model1             |   0 |
# | team_id            |   0 |
# | OS3                |   0 |
# | OS2                |   0 |
# | OS1                |   0 |
# | OpenCL score4      |   0 |
# ...

# %% [markdown]
# ## **Replacing null values in single and multi core scores**

# %%
columns = ['Single core score1', 'Single core score2', 'Single core score3', 'Single core score4', 'Multi core score1', 'Multi core score2', 'Multi core score3', 'Multi core score4']
def Replace_null(columns):
  for cols in columns:
    pc_details[cols] = pc_details[cols].fillna(0)
  return pc_details

pc_details = Replace_null(columns)

# %%
print(pc_details.isna().sum().sort_values(ascending=False).to_markdown())
# Out:
# |                    |   0 |
# |:-------------------|----:|
# | Unnamed: 0         |   0 |
# | CPU4               |   0 |
# | Model2             |   0 |
# | Model3             |   0 |
# | Model4             |   0 |
# | CPU1               |   0 |
# | CPU2               |   0 |
# | CPU3               |   0 |
# | Memory1            |   0 |
# | team_id            |   0 |
# | Memory2            |   0 |
# | Memory3            |   0 |
# | Memory4            |   0 |
# | Graphic Card1      |   0 |
# | Graphic Card2      |   0 |
# | Graphic Card3      |   0 |
# | Model1             |   0 |
# | OS4                |   0 |
# | OS3                |   0 |
# | OS2                |   0 |
# | OS1                |   0 |
# | OpenCL score4      |   0 |
# | OpenCL score3      |   0 |
# | OpenCL score2      |   0 |
# | OpenCL score1      |   0 |
# | Multi core score4  |   0 |
# | Multi core score3  |   0 |
# | Multi core score2  |   0 |
# | Multi core score1  |   0 |
# | Single core score4 |   0 |
# ...

# %%
pc_details.head()
# Out:
#    Unnamed: 0  team_id  Single core score1  Single core score2  \
# 0           0     1001              1142.0               543.0
# 1           1     1002              1060.0               549.0
# 2           2     1004               809.0              1182.0
# 3           3     1005               686.0              1003.0
# 4           4     1006              1004.0               422.0
#
#    Single core score3  Single core score4  Multi core score1  \
# 0               836.0               601.0             2148.0
# 1               416.0               590.0             3394.0
# 2               847.0               770.0             2303.0
# 3               624.0               827.0             3318.0
# 4               657.0              1121.0             2612.0
#
#    Multi core score2  Multi core score3  Multi core score4  ...  \
# 0             1132.0             1525.0             2281.0  ...
# 1             1834.0              857.0             1326.0  ...
# ...

# %%
pc_details.to_csv('Cleaned_pc_specs4.csv', index = True)
